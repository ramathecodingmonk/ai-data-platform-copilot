# %% [markdown]
# <a href="https://colab.research.google.com/github/ramathecodingmonk/ai-data-platform-copilot/blob/llm_fundamentals_notes/Transformers_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
import transformers
